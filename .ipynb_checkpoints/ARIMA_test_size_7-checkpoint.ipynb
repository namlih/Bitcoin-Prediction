# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/namlih/Bitcoin-Prediction/blob/master/ARIMA_test_size_7.ipynb)

# %%
from pandas import *
from matplotlib import pyplot
from sklearn.metrics import mean_squared_error, accuracy_score
from sklearn.preprocessing import MinMaxScaler
from math import sqrt
import matplotlib
import numpy
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.arima_model import ARIMA
import warnings
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
import requests
binance  = "https://www.binance.com/api/v1/klines?symbol=BTCUSDT&interval=1d"
r = requests.get(binance)
data = r.json()

from math import log10
df = DataFrame(columns=["price"])
for row in data:
    df = df.append(DataFrame([float(row[1])],columns=df.columns))
df.index = [i for i in range(df.shape[0])]
df
# Out:
#        price
# 0    4261.48
# 1    4285.08
# 2    4108.37
# 3    4120.98
# 4    4069.13
# 5    4016.00
# 6    4040.00
# 7    4147.00
# 8    4316.01
# 9    4280.71
# 10   4332.51
# 11   4310.01
# 12   4353.65
# 13   4564.52
# 14   4555.14
# 15   4689.89
# 16   4796.16
# 17   4508.50
# 18   4505.00
# 19   4106.97
# 20   4366.49
# 21   4619.77
# 22   4691.66
# 23   4282.80
# 24   4258.81
# 25   4153.62
# 26   4208.60
# 27   4159.72
# 28   3944.00
# 29   3188.01
# ..       ...
# 229  7063.97
# 230  7405.21
# 231  6796.10
# 232  6770.00
# 233  6601.39
# 234  6895.81
# 235  7011.04
# 236  6781.55
# 237  6839.56
# 238  6953.78
# 239  7922.99
# 240  7877.48
# 241  8004.00
# 242  8355.07
# 243  8064.92
# 244  7890.96
# 245  8173.99
# 246  8273.84
# 247  8852.12
# 248  8915.31
# 249  8785.70
# 250  8934.00
# 251  9618.96
# 252  8869.99
# 253  9267.03
# 254  8915.35
# 255  9348.00
# 256  9417.04
# 257  9246.01
# 258  9071.48
#
# [259 rows x 1 columns]

# %%
# invert differenced value
def inverse_difference(history, yhat, interval=1):
    return yhat + history[-interval]

# create a differenced series
def difference_arima(dataset, interval=1):
    diff = list()
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value) 
    return diff

# evaluate an ARIMA model for a given order (p,d,q) and return RMSE
def evaluate_arima_model(X, test_size, arima_order):
    # prepare training dataset
    X = X.astype('float32')
    train, test = X[0:-test_size], X[-test_size:]
    history = [x for x in train]
    # make predictions
    predictions = list()
    for t in range(len(test)):
        # difference data
        interval = 7
        diff = difference_arima(history, interval)
        
        model = ARIMA(diff, order=arima_order)
        model_fit = model.fit(trend='nc', disp=0)
        yhat = model_fit.forecast()[0]
        yhat = inverse_difference(history, yhat, interval)
        predictions.append(yhat)
        history.append(test[t])
    # calculate out of sample error
    mse = mean_squared_error(test, predictions)
    rmse = sqrt(mse)
    return rmse,predictions

# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(dataset, test_size,p_values, d_values, q_values):
    dataset = dataset.astype('float32')
    best_score, best_cfg = float("inf"), None
    preds = list()
    best_preds = list()
    for p in p_values:
        for d in d_values:
            for q in q_values:
                order = (p,d,q)
                try:
                    #print(order)
                    mse,preds = evaluate_arima_model(dataset, test_size, order)
                    if mse < best_score:
                        best_score, best_cfg = mse, order
                        best_preds = [p for p in preds]
                    print('ARIMA%s RMSE=%.3f' % (order,mse))
                except:
                    continue
    print('Best ARIMA%s RMSE=%.3f' % (best_cfg, best_score))
    return best_preds

# %%
import time
p_values = range(0, 7)
d_values = range(0, 7)
q_values = range(0, 7)

warnings.filterwarnings("ignore")
test_size=7
date_index = date_range('08-01-2017',periods=df.shape[0],freq='D')
series = Series(df['price'].values,index=date_index)

st = time.time()
predictions = evaluate_models(series.values,test_size, p_values, d_values, q_values)
ft = time.time()
# Out:
# ARIMA(0, 0, 1) RMSE=796.244
# ARIMA(0, 1, 1) RMSE=703.980
# ARIMA(0, 1, 2) RMSE=724.984
# ARIMA(0, 1, 3) RMSE=727.720
# ARIMA(0, 1, 4) RMSE=669.768
# ARIMA(0, 1, 5) RMSE=675.223
# ARIMA(0, 1, 6) RMSE=650.102
# ARIMA(0, 2, 1) RMSE=659.873
# ARIMA(0, 2, 2) RMSE=706.835
# ARIMA(1, 0, 0) RMSE=579.485
# ARIMA(1, 0, 1) RMSE=646.031
# ARIMA(1, 0, 2) RMSE=650.031
# ARIMA(1, 0, 3) RMSE=667.180
# ARIMA(1, 0, 4) RMSE=650.585
# ARIMA(1, 0, 5) RMSE=468.141
# ARIMA(1, 0, 6) RMSE=499.520
# ARIMA(1, 1, 0) RMSE=693.982
# ARIMA(1, 1, 1) RMSE=735.498
# ARIMA(1, 1, 2) RMSE=654.310
# ARIMA(1, 1, 3) RMSE=659.136
# ARIMA(1, 1, 4) RMSE=670.360
# ARIMA(1, 1, 5) RMSE=677.615
# ARIMA(1, 1, 6) RMSE=473.244
# ARIMA(1, 2, 0) RMSE=884.966
# ARIMA(1, 2, 1) RMSE=696.738
# ARIMA(1, 2, 2) RMSE=737.999
# ARIMA(1, 2, 3) RMSE=738.103
# ARIMA(1, 2, 4) RMSE=737.423
# ARIMA(1, 2, 5) RMSE=684.207
# ARIMA(1, 2, 6) RMSE=637.577
# ARIMA(2, 0, 0) RMSE=635.386
# ARIMA(2, 0, 1) RMSE=667.768
# ARIMA(2, 0, 2) RMSE=631.528
# ARIMA(2, 0, 3) RMSE=634.428
# ARIMA(2, 0, 4) RMSE=603.387
# ARIMA(2, 0, 5) RMSE=468.973
# ARIMA(2, 0, 6) RMSE=504.832
# ARIMA(2, 1, 0) RMSE=711.617
# ARIMA(2, 1, 1) RMSE=643.697
# ARIMA(2, 1, 2) RMSE=671.733
# ARIMA(2, 1, 3) RMSE=721.509
# ARIMA(2, 1, 4) RMSE=633.782
# ARIMA(2, 1, 5) RMSE=569.456
# ARIMA(2, 1, 6) RMSE=474.440
# ARIMA(2, 2, 0) RMSE=881.122
# ARIMA(2, 2, 1) RMSE=713.407
# ARIMA(2, 2, 2) RMSE=738.397
# ARIMA(2, 2, 3) RMSE=589.705
# ARIMA(2, 2, 4) RMSE=578.823
# ARIMA(2, 2, 5) RMSE=635.280
# ARIMA(2, 2, 6) RMSE=558.068
# ARIMA(3, 0, 0) RMSE=638.105
# ARIMA(3, 0, 1) RMSE=658.247
# ARIMA(3, 0, 2) RMSE=667.475
# ARIMA(3, 0, 3) RMSE=553.369
# ARIMA(3, 0, 4) RMSE=664.822
# ARIMA(3, 0, 5) RMSE=474.136
# ARIMA(3, 0, 6) RMSE=457.264
# ARIMA(3, 1, 0) RMSE=710.106
# ARIMA(3, 1, 1) RMSE=647.171
# ARIMA(3, 1, 2) RMSE=665.926
# ARIMA(3, 1, 3) RMSE=769.958
# ARIMA(3, 1, 4) RMSE=579.085
# ARIMA(3, 1, 5) RMSE=580.970
# ARIMA(3, 1, 6) RMSE=478.071
# ARIMA(3, 2, 0) RMSE=822.936
# ARIMA(3, 2, 1) RMSE=712.662
# ARIMA(3, 2, 2) RMSE=689.064
# ARIMA(3, 2, 3) RMSE=585.773
# ARIMA(3, 2, 4) RMSE=767.664
# ARIMA(3, 2, 5) RMSE=634.761
# ARIMA(3, 2, 6) RMSE=552.551
# ARIMA(4, 0, 0) RMSE=649.575
# ARIMA(4, 0, 1) RMSE=637.500
# ARIMA(4, 0, 2) RMSE=659.435
# ARIMA(4, 0, 3) RMSE=564.057
# ARIMA(4, 0, 4) RMSE=585.187
# ARIMA(4, 0, 5) RMSE=485.708
# ARIMA(4, 0, 6) RMSE=558.614
# ARIMA(4, 1, 0) RMSE=723.053
# ARIMA(4, 1, 1) RMSE=749.158
# ARIMA(4, 1, 2) RMSE=584.988
# ARIMA(4, 1, 3) RMSE=558.886
# ARIMA(4, 1, 4) RMSE=602.466
# ARIMA(4, 1, 5) RMSE=580.038
# ARIMA(4, 1, 6) RMSE=488.552
# ARIMA(4, 2, 0) RMSE=823.367
# ARIMA(4, 2, 1) RMSE=821.278
# ARIMA(4, 2, 2) RMSE=807.107
# ARIMA(4, 2, 3) RMSE=586.203
# ARIMA(4, 2, 4) RMSE=623.477
# ARIMA(4, 2, 5) RMSE=613.260
# ARIMA(4, 2, 6) RMSE=582.690
# ARIMA(5, 0, 0) RMSE=652.547
# ARIMA(5, 0, 1) RMSE=636.217
# ARIMA(5, 0, 2) RMSE=576.446
# ARIMA(5, 0, 5) RMSE=489.603
# ARIMA(5, 0, 6) RMSE=535.676
# ARIMA(5, 1, 0) RMSE=741.418
# ARIMA(5, 1, 1) RMSE=758.921
# ARIMA(5, 1, 2) RMSE=606.030
# ARIMA(5, 1, 3) RMSE=577.423
# ARIMA(5, 1, 4) RMSE=575.210
# ARIMA(5, 1, 5) RMSE=680.102
# ARIMA(5, 1, 6) RMSE=492.108
# ARIMA(5, 2, 0) RMSE=819.144
# ARIMA(5, 2, 1) RMSE=830.199
# ARIMA(5, 2, 2) RMSE=690.350
# ARIMA(5, 2, 3) RMSE=605.874
# ARIMA(5, 2, 4) RMSE=608.893
# ARIMA(5, 2, 5) RMSE=545.580
# ARIMA(5, 2, 6) RMSE=577.102
# ARIMA(6, 0, 0) RMSE=664.224
# ARIMA(6, 0, 1) RMSE=673.769
# ARIMA(6, 0, 2) RMSE=618.252
# ARIMA(6, 0, 3) RMSE=529.261
# ARIMA(6, 0, 4) RMSE=426.123
# ARIMA(6, 0, 5) RMSE=483.234
# ARIMA(6, 0, 6) RMSE=570.629
# ARIMA(6, 1, 0) RMSE=828.492
# ARIMA(6, 1, 1) RMSE=676.221
# ARIMA(6, 1, 2) RMSE=691.724
# ARIMA(6, 1, 3) RMSE=555.579
# ARIMA(6, 1, 4) RMSE=513.711
# ARIMA(6, 1, 5) RMSE=494.361
# ARIMA(6, 1, 6) RMSE=484.364
# ARIMA(6, 2, 0) RMSE=721.368
# ARIMA(6, 2, 1) RMSE=655.950
# ARIMA(6, 2, 2) RMSE=683.207
# ARIMA(6, 2, 3) RMSE=610.437
# ARIMA(6, 2, 4) RMSE=555.157
# Best ARIMA(6, 0, 4) RMSE=426.123

# %%
if type(predictions[0]) != numpy.float64:
    _preds = list()
    for x in predictions:
        _preds.append(x[0])
else: _preds = [p for p in predictions]

# %%
ft-st
# Out:
# 564.2971794605255

# %%
def sMAPE(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / ((y_true + y_pred)/2) )) * 100
sMAPE(df['price'].values[-test_size:],_preds)
# Out:
# 3.7134585472544486

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

rms = sqrt(mean_squared_error(df['price'][-test_size:], _preds))
rms
# Out:
# 426.12269725292913

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(18,6))
plt.plot(Series(df['price'].values,index=range(df.shape[0])),label="real")
plt.plot(Series(_preds,index=range(df.shape[0]-test_size,df.shape[0])),label="prediction")
plt.legend()
plt.show()
