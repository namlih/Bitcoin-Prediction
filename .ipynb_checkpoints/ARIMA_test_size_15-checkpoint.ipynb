# %%
from pandas import *
from matplotlib import pyplot
from sklearn.metrics import mean_squared_error, accuracy_score
from sklearn.preprocessing import MinMaxScaler
from math import sqrt
import matplotlib
import numpy
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.arima_model import ARIMA
import warnings
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
import requests
binance  = "https://www.binance.com/api/v1/klines?symbol=BTCUSDT&interval=1d"
r = requests.get(binance)
data = r.json()

from math import log10
df = DataFrame(columns=["price"])
for row in data:
    df = df.append(DataFrame([float(row[1])],columns=df.columns))
df.index = [i for i in range(df.shape[0])]
df
# Out:
#        price
# 0    4261.48
# 1    4285.08
# 2    4108.37
# 3    4120.98
# 4    4069.13
# 5    4016.00
# 6    4040.00
# 7    4147.00
# 8    4316.01
# 9    4280.71
# 10   4332.51
# 11   4310.01
# 12   4353.65
# 13   4564.52
# 14   4555.14
# 15   4689.89
# 16   4796.16
# 17   4508.50
# 18   4505.00
# 19   4106.97
# 20   4366.49
# 21   4619.77
# 22   4691.66
# 23   4282.80
# 24   4258.81
# 25   4153.62
# 26   4208.60
# 27   4159.72
# 28   3944.00
# 29   3188.01
# ..       ...
# 229  7063.97
# 230  7405.21
# 231  6796.10
# 232  6770.00
# 233  6601.39
# 234  6895.81
# 235  7011.04
# 236  6781.55
# 237  6839.56
# 238  6953.78
# 239  7922.99
# 240  7877.48
# 241  8004.00
# 242  8355.07
# 243  8064.92
# 244  7890.96
# 245  8173.99
# 246  8273.84
# 247  8852.12
# 248  8915.31
# 249  8785.70
# 250  8934.00
# 251  9618.96
# 252  8869.99
# 253  9267.03
# 254  8915.35
# 255  9348.00
# 256  9417.04
# 257  9246.01
# 258  9071.48
#
# [259 rows x 1 columns]

# %%
# invert differenced value
def inverse_difference(history, yhat, interval=1):
    return yhat + history[-interval]

# create a differenced series
def difference_arima(dataset, interval=1):
    diff = list()
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value) 
    return diff

# evaluate an ARIMA model for a given order (p,d,q) and return RMSE
def evaluate_arima_model(X, test_size, arima_order):
    # prepare training dataset
    X = X.astype('float32')
    train, test = X[0:-test_size], X[-test_size:]
    history = [x for x in train]
    # make predictions
    predictions = list()
    for t in range(len(test)):
        # difference data
        interval = 7
        diff = difference_arima(history, interval)
        
        model = ARIMA(diff, order=arima_order)
        model_fit = model.fit(trend='nc', disp=0)
        yhat = model_fit.forecast()[0]
        yhat = inverse_difference(history, yhat, interval)
        predictions.append(yhat)
        history.append(test[t])
    # calculate out of sample error
    mse = mean_squared_error(test, predictions)
    rmse = sqrt(mse)
    return rmse,predictions

# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(dataset, test_size,p_values, d_values, q_values):
    dataset = dataset.astype('float32')
    best_score, best_cfg = float("inf"), None
    preds = list()
    best_preds = list()
    for p in p_values:
        for d in d_values:
            for q in q_values:
                order = (p,d,q)
                try:
                    #print(order)
                    mse,preds = evaluate_arima_model(dataset, test_size, order)
                    if mse < best_score:
                        best_score, best_cfg = mse, order
                        best_preds = [p for p in preds]
                    print('ARIMA%s RMSE=%.3f' % (order,mse))
                except:
                    continue
    print('Best ARIMA%s RMSE=%.3f' % (best_cfg, best_score))
    return best_preds

# %%
import time
p_values = range(0, 7)
d_values = range(0, 7)
q_values = range(0, 7)

warnings.filterwarnings("ignore")
test_size=15
date_index = date_range('08-01-2017',periods=df.shape[0],freq='D')
series = Series(df['price'].values,index=date_index)

st = time.time()
predictions = evaluate_models(series.values,test_size, p_values, d_values, q_values)
ft = time.time()
# Out:
# ARIMA(0, 0, 1) RMSE=772.035
# ARIMA(0, 1, 1) RMSE=633.626
# ARIMA(0, 1, 2) RMSE=639.824
# ARIMA(0, 1, 3) RMSE=641.034
# ARIMA(0, 1, 4) RMSE=621.377
# ARIMA(0, 1, 5) RMSE=602.750
# ARIMA(0, 1, 6) RMSE=583.886
# ARIMA(0, 2, 1) RMSE=602.216
# ARIMA(0, 2, 2) RMSE=635.324
# ARIMA(1, 0, 0) RMSE=561.727
# ARIMA(1, 0, 1) RMSE=607.503
# ARIMA(1, 0, 2) RMSE=608.816
# ARIMA(1, 0, 3) RMSE=616.241
# ARIMA(1, 0, 4) RMSE=614.641
# ARIMA(1, 0, 5) RMSE=474.407
# ARIMA(1, 0, 6) RMSE=440.790
# ARIMA(1, 1, 0) RMSE=627.243
# ARIMA(1, 1, 1) RMSE=646.709
# ARIMA(1, 1, 2) RMSE=608.020
# ARIMA(1, 1, 3) RMSE=609.626
# ARIMA(1, 1, 4) RMSE=609.312
# ARIMA(1, 1, 5) RMSE=603.783
# ARIMA(1, 1, 6) RMSE=475.509
# ARIMA(1, 2, 0) RMSE=787.418
# ARIMA(1, 2, 1) RMSE=628.965
# ARIMA(1, 2, 2) RMSE=648.056
# ARIMA(1, 2, 3) RMSE=646.616
# ARIMA(1, 2, 4) RMSE=646.305
# ARIMA(1, 2, 5) RMSE=611.057
# ARIMA(1, 2, 6) RMSE=566.193
# ARIMA(2, 0, 0) RMSE=604.394
# ARIMA(2, 0, 1) RMSE=613.668
# ARIMA(2, 0, 2) RMSE=606.649
# ARIMA(2, 0, 3) RMSE=604.720
# ARIMA(2, 0, 4) RMSE=564.372
# ARIMA(2, 0, 5) RMSE=478.858
# ARIMA(2, 0, 6) RMSE=471.147
# ARIMA(2, 1, 0) RMSE=634.646
# ARIMA(2, 1, 1) RMSE=604.481
# ARIMA(2, 1, 2) RMSE=647.367
# ARIMA(2, 1, 3) RMSE=662.590
# ARIMA(2, 1, 4) RMSE=555.948
# ARIMA(2, 1, 5) RMSE=497.449
# ARIMA(2, 1, 6) RMSE=479.218
# ARIMA(2, 2, 0) RMSE=748.830
# ARIMA(2, 2, 1) RMSE=635.918
# ARIMA(2, 2, 2) RMSE=646.796
# ARIMA(2, 2, 3) RMSE=550.806
# ARIMA(2, 2, 4) RMSE=545.983
# ARIMA(2, 2, 5) RMSE=557.449
# ARIMA(2, 2, 6) RMSE=533.950
# ARIMA(3, 0, 0) RMSE=605.415
# ARIMA(3, 0, 1) RMSE=612.475
# ARIMA(3, 0, 2) RMSE=562.264
# ARIMA(3, 0, 3) RMSE=540.334
# ARIMA(3, 0, 4) RMSE=553.563
# ARIMA(3, 0, 5) RMSE=479.927
# ARIMA(3, 0, 6) RMSE=427.867
# ARIMA(3, 1, 0) RMSE=634.565
# ARIMA(3, 1, 1) RMSE=605.811
# ARIMA(3, 1, 2) RMSE=639.480
# ARIMA(3, 1, 3) RMSE=696.677
# ARIMA(3, 1, 4) RMSE=536.927
# ARIMA(3, 1, 5) RMSE=532.561
# ARIMA(3, 1, 6) RMSE=481.168
# ARIMA(3, 2, 0) RMSE=720.494
# ARIMA(3, 2, 1) RMSE=636.028
# ARIMA(3, 2, 2) RMSE=620.402
# ARIMA(3, 2, 3) RMSE=549.096
# ARIMA(3, 2, 4) RMSE=691.388
# ARIMA(3, 2, 5) RMSE=558.033
# ARIMA(3, 2, 6) RMSE=530.756
# ARIMA(4, 0, 0) RMSE=609.162
# ARIMA(4, 0, 1) RMSE=607.926
# ARIMA(4, 0, 2) RMSE=639.028
# ARIMA(4, 0, 3) RMSE=634.136
# ARIMA(4, 0, 4) RMSE=551.658
# ARIMA(4, 0, 5) RMSE=486.633
# ARIMA(4, 0, 6) RMSE=458.780
# ARIMA(4, 1, 0) RMSE=638.352
# ARIMA(4, 1, 1) RMSE=654.875
# ARIMA(4, 1, 2) RMSE=527.231
# ARIMA(4, 1, 3) RMSE=534.750
# ARIMA(4, 1, 4) RMSE=575.591
# ARIMA(4, 1, 5) RMSE=533.269
# ARIMA(4, 1, 6) RMSE=486.539
# ARIMA(4, 2, 0) RMSE=729.601
# ARIMA(4, 2, 1) RMSE=728.517
# ARIMA(4, 2, 2) RMSE=690.898
# ARIMA(4, 2, 3) RMSE=528.417
# ARIMA(4, 2, 4) RMSE=546.146
# ARIMA(4, 2, 5) RMSE=553.878
# ARIMA(4, 2, 6) RMSE=550.927
# ARIMA(5, 0, 0) RMSE=610.077
# ARIMA(5, 0, 1) RMSE=607.963
# ARIMA(5, 0, 2) RMSE=608.183
# ARIMA(5, 0, 5) RMSE=483.561
# ARIMA(5, 0, 6) RMSE=482.739
# ARIMA(5, 1, 0) RMSE=657.729
# ARIMA(5, 1, 1) RMSE=667.930
# ARIMA(5, 1, 2) RMSE=532.701
# ARIMA(5, 1, 4) RMSE=523.342
# ARIMA(5, 1, 5) RMSE=545.564
# ARIMA(5, 1, 6) RMSE=482.981
# ARIMA(5, 2, 0) RMSE=727.411
# ARIMA(5, 2, 1) RMSE=733.349
# ARIMA(5, 2, 2) RMSE=616.156
# ARIMA(5, 2, 3) RMSE=533.014
# ARIMA(5, 2, 4) RMSE=535.169
# ARIMA(5, 2, 5) RMSE=522.551
# ARIMA(5, 2, 6) RMSE=546.727
# ARIMA(6, 0, 0) RMSE=636.543
# ARIMA(6, 0, 1) RMSE=641.341
# ARIMA(6, 0, 2) RMSE=579.206
# ARIMA(6, 0, 3) RMSE=505.361
# ARIMA(6, 0, 4) RMSE=500.083
# ARIMA(6, 0, 5) RMSE=480.874
# ARIMA(6, 0, 6) RMSE=474.880
# ARIMA(6, 1, 0) RMSE=704.798
# ARIMA(6, 1, 1) RMSE=648.464
# ARIMA(6, 1, 2) RMSE=644.358
# ARIMA(6, 1, 3) RMSE=513.170
# ARIMA(6, 1, 4) RMSE=470.801
# ARIMA(6, 1, 5) RMSE=464.378
# ARIMA(6, 1, 6) RMSE=479.545
# ARIMA(6, 2, 0) RMSE=672.628
# ARIMA(6, 2, 1) RMSE=634.513
# ARIMA(6, 2, 2) RMSE=599.108
# ARIMA(6, 2, 3) RMSE=536.170
# ARIMA(6, 2, 4) RMSE=504.816
# Best ARIMA(3, 0, 6) RMSE=427.867

# %%
if type(predictions[0]) != numpy.float64:
    _preds = list()
    for x in predictions:
        _preds.append(x[0])
else: _preds = [p for p in predictions]

# %%
ft-st
# Out:
# 1133.3319990634918

# %%
def sMAPE(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / ((y_true + y_pred)/2) )) * 100
sMAPE(df['price'].values[-test_size:],_preds)
# Out:
# 4.5120024578651803

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

rms = sqrt(mean_squared_error(df['price'][-test_size:], _preds))
rms
# Out:
# 427.86679949967805

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(18,6))
plt.plot(Series(df['price'].values,index=range(df.shape[0])),label="real")
plt.plot(Series(_preds,index=range(df.shape[0]-test_size,df.shape[0])),label="prediction")
plt.legend()
plt.show()
