# %%
import pandas as pd
import numpy as np
import requests
binance  = "https://www.binance.com/api/v1/klines?symbol=BTCUSDT&interval=1d"
r = requests.get(binance)
data = r.json()

df = pd.DataFrame(columns=["price"])
for row in data:
    df = df.append(pd.DataFrame([float(row[1])],columns=df.columns))
df.index = [i for i in range(df.shape[0])]
df
# Out:
#        price
# 0    4261.48
# 1    4285.08
# 2    4108.37
# 3    4120.98
# 4    4069.13
# 5    4016.00
# 6    4040.00
# 7    4147.00
# 8    4316.01
# 9    4280.71
# 10   4332.51
# 11   4310.01
# 12   4353.65
# 13   4564.52
# 14   4555.14
# 15   4689.89
# 16   4796.16
# 17   4508.50
# 18   4505.00
# 19   4106.97
# 20   4366.49
# 21   4619.77
# 22   4691.66
# 23   4282.80
# 24   4258.81
# 25   4153.62
# 26   4208.60
# 27   4159.72
# 28   3944.00
# 29   3188.01
# ..       ...
# 229  7063.97
# 230  7405.21
# 231  6796.10
# 232  6770.00
# 233  6601.39
# 234  6895.81
# 235  7011.04
# 236  6781.55
# 237  6839.56
# 238  6953.78
# 239  7922.99
# 240  7877.48
# 241  8004.00
# 242  8355.07
# 243  8064.92
# 244  7890.96
# 245  8173.99
# 246  8273.84
# 247  8852.12
# 248  8915.31
# 249  8785.70
# 250  8934.00
# 251  9618.96
# 252  8869.99
# 253  9267.03
# 254  8915.35
# 255  9348.00
# 256  9417.04
# 257  9246.01
# 258  9071.48
#
# [259 rows x 1 columns]

# %%
from fbprophet import Prophet
import time

test_size = 30
date_index = pd.date_range('08-01-2017',periods=df.shape[0]-30,freq='D')
btc = pd.DataFrame({'ds':date_index, 'y':df['price'].values[:-30]})

st = time.time()
m = Prophet().fit(btc)
ft = time.time()

future = m.make_future_dataframe(periods=30)
fcst = m.predict(future)
m.plot(fcst)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-90c5c149f478> in <module>()
#       2 date_index = pd.date_range('08-01-2017',periods=df.shape[0]-30,freq='D')
#       3 btc = pd.DataFrame({'ds':date_index, 'y':df['price'].values[:-30]})
# ----> 4 st = time.time()
#       5 m = Prophet().fit(btc)
#       6 future = m.make_future_dataframe(periods=30)
#
# NameError: name 'time' is not defined

# %%
def sMAPE(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / ((y_true + y_pred)/2) )) * 100
# Out:
# 8.4963211448536988

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(18,6))
plt.plot(pd.Series(df['price'].values,index=range(df.shape[0])),label="real")
plt.plot(pd.Series(fcst['yhat'].values,index=range(df.shape[0])),label="prediction")
#plt.plot(pd.Series(preds,index=range(df.shape[0]-test_size,df.shape[0])),label="prediction")
plt.legend()
plt.show()

# %%
sMAPE(df['price'][-30:],fcst['yhat'][-30:])
# Out:
# 9.7331741436300021

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

rms = sqrt(mean_squared_error(df['price'][-30:], fcst['yhat'][-30:]))
rms
# Out:
# 932.1248439928343
